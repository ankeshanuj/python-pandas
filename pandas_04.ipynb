# %%
import pandas as pd

# %%
df = pd.read_csv("LEAVE_CALCULATION.csv")

# %%
df
# Out:
#          CODE                NAME                 DESIGNATION   PLACE/SITE  \
# 0    JKEPL001      Deepak tripathi                Mech. Engg.    Malmaliya
# 1    JKEPL002   Arbind kumar singh                   Lab Tech      Chhapra
# 2    JKEPL003          Anish Kumar               Store Keeper    Malmaliya
# 3    JKEPL004        Praduman Giri                 Supervisor    Malmaliya
# 4    JKEPL005  Ranjeet Kumar singh                 Supervisor    Malmaliya
# ..        ...                  ...                        ...          ...
# 190  JKEPL192   ARUN VISWNATH RAY              RANTEL TRACTOR      DAUDPUR
# 191  JKEPL193             OM SINGH  RENTAL TRACTOR\nSONALIKA    SAHAJITPUR
# 192  JKEPL194            RAMPUKAR        HYVA DRIVER (Rental)    MALMALIYA
# 193  JKEPL195          ANUP PANDEY             RENTAL TRACTOR  RACK POINT
# 194  JKEPL196          DHARMENDRA                  HYDRA OPT.  RACK POINT
#
#       JAN  LEAVE CALCULATION   FEB  LEAVE CALCULATION.1  MARCH  \
# ...

# %%
 df = pd.read_csv("LEAVE_CALCULATION.csv", na_values={
    'MAY': ["#REF!"],
})

# %%
df
# Out:
#          CODE                NAME                 DESIGNATION   PLACE/SITE  \
# 0    JKEPL001      Deepak tripathi                Mech. Engg.    Malmaliya
# 1    JKEPL002   Arbind kumar singh                   Lab Tech      Chhapra
# 2    JKEPL003          Anish Kumar               Store Keeper    Malmaliya
# 3    JKEPL004        Praduman Giri                 Supervisor    Malmaliya
# 4    JKEPL005  Ranjeet Kumar singh                 Supervisor    Malmaliya
# ..        ...                  ...                        ...          ...
# 190  JKEPL192   ARUN VISWNATH RAY              RANTEL TRACTOR      DAUDPUR
# 191  JKEPL193             OM SINGH  RENTAL TRACTOR\nSONALIKA    SAHAJITPUR
# 192  JKEPL194            RAMPUKAR        HYVA DRIVER (Rental)    MALMALIYA
# 193  JKEPL195          ANUP PANDEY             RENTAL TRACTOR  RACK POINT
# 194  JKEPL196          DHARMENDRA                  HYDRA OPT.  RACK POINT
#
#       JAN  LEAVE CALCULATION   FEB  LEAVE CALCULATION.1  MARCH  \
# ...
