# %%
import pandas as pd

# %%
asdf = pd.read_csv("./PAYMENT_SHEET.csv")

# %%
asdf
# Out:
#          Code                   Name        Designation      Site/Branches  \
# 0    JKEPL001  Deepak Kumar Tripathi     Mech. Engineer             Bagha
# 1    JKEPL002     Arbind kumar singh           Lab Tech        RACK POINT
# 2    JKEPL004          Praduman Giri         Supervisor       EKMA-MASRAKH
# 3    JKEPL005    Ranjeet Kumar singh         Supervisor          Malmaliya
# 4    JKEPL006               Pradhan               Guard      DAUDPUR PLANT
# ..        ...                    ...                ...                ...
# 109  JKEPL240      Bhavishaya Kumar               Guard  Indra-Doharighat
# 110  JKEPL241          Pankaj kumar      Fiori Helpher   Indra-Doharighat
# 111  JKEPL242     Vikki kumar singh   Surveyer Helpher         RACK POINT
# 112  JKEPL243           Rajesh Giri               Cook        EKMA-MASRAKH
# 113       NaN                    NaN                NaN                NaN
#
# ...

# %%
asdf['Salary'].max()
# Out:
# 55000.0

# %%
asdf['Salary'].mean()
# Out:
# 14259.545454545454

# %%
asdf['Salary'][asdf['DATE OF JOINING']=='Rain']
# Out:
# Series([], Name: Salary, dtype: float64)

# %%
print("Hello world")
