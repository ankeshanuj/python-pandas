# %%
import pandas as pd
df = pd.read_csv("appledata.csv", parse_dates=["Date"])
df.head(5)
# Out:
#         Date     Open    High      Low   Close     Volume
# 0 2022-12-02  145.960  148.00  145.650  147.81   65447450
# 1 2022-12-01  148.210  149.13  146.610  148.31   71250420
# 2 2022-11-30  141.395  148.72  140.550  148.03  111380900
# 3 2022-11-29  144.290  144.81  140.355  141.17   83763800
# 4 2022-11-28  145.140  146.64  143.380  144.22   69346520

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv("appledata.csv", parse_dates=["Date"], index_col="Date")
df.head(5)
# Out:
#                Open    High      Low   Close     Volume
# Date
# 2022-12-02  145.960  148.00  145.650  147.81   65447450
# 2022-12-01  148.210  149.13  146.610  148.31   71250420
# 2022-11-30  141.395  148.72  140.550  148.03  111380900
# 2022-11-29  144.290  144.81  140.355  141.17   83763800
# 2022-11-28  145.140  146.64  143.380  144.22   69346520

# %%
df.index
# Out:
# DatetimeIndex(['2022-12-02', '2022-12-01', '2022-11-30', '2022-11-29',
#                '2022-11-28', '2022-11-25', '2022-11-23', '2022-11-22',
#                '2022-11-21', '2022-11-18',
#                ...
#                '2021-12-16', '2021-12-15', '2021-12-14', '2021-12-13',
#                '2021-12-10', '2021-12-09', '2021-12-08', '2021-12-07',
#                '2021-12-06', '2021-12-03'],
#               dtype='datetime64[ns]', name='Date', length=252, freq=None)

# %%
df["2022-1"]
# Out:
# C:\Users\ankes\AppData\Local\Temp\ipykernel_18292\1031140938.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2022-1"]
#                Open      High      Low   Close     Volume
# Date
# 2022-01-31  170.160  175.0000  169.510  174.78  115541600
# 2022-01-28  165.710  170.3500  162.800  170.33  179935700
# 2022-01-27  162.450  163.8400  158.280  159.22  121954600
# 2022-01-26  163.500  164.3894  157.820  159.69  108275300
# 2022-01-25  158.980  162.7600  157.020  159.78  115798400
# 2022-01-24  160.020  162.3000  154.700  161.62  162706700
# 2022-01-21  164.415  166.3300  162.300  162.41  122848900
# 2022-01-20  166.980  169.6800  164.180  164.51   91420520
# 2022-01-19  170.000  171.0800  165.940  166.23   94814990
# 2022-01-18  171.510  172.5400  169.405  169.80   91168730
# 2022-01-14  171.340  173.7800  171.090  173.07   80440780
# 2022-01-13  175.780  176.6200  171.790  172.19   84505760
# 2022-01-12  176.120  177.1800  174.820  175.53   74805170
# 2022-01-11  172.320  175.1800  170.820  175.08   76138310
# 2022-01-10  169.080  172.5000  168.170  172.19  106765600
# 2022-01-07  172.890  174.1400  171.030  172.17   86709150
# 2022-01-06  172.700  175.3000  171.640  172.00   96903960
# 2022-01-05  179.610  180.1700  174.640  174.92   94537600
# 2022-01-04  182.630  182.9400  179.120  179.70   99310440
# 2022-01-03  177.830  182.8800  177.710  182.01  104701200

# %%
df["2022-1"].Close.mean()
# Out:
# C:\Users\ankes\AppData\Local\Temp\ipykernel_18292\2265802943.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2022-1"].Close.mean()
# 169.86149999999998

# %%
df["2022-01-07":"2022-01-12"]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2022-01-12  176.12  177.18  174.82  175.53   74805170
# 2022-01-11  172.32  175.18  170.82  175.08   76138310
# 2022-01-10  169.08  172.50  168.17  172.19  106765600
# 2022-01-07  172.89  174.14  171.03  172.17   86709150

# %%
df.Close.resample('M').mean()
# Out:
# Date
# 2021-12-31    174.481500
# 2022-01-31    169.861500
# 2022-02-28    169.830000
# 2022-03-31    165.310435
# 2022-04-30    166.821000
# 2022-05-31    148.430476
# 2022-06-30    139.798571
# 2022-07-31    149.670500
# 2022-08-31    166.885217
# 2022-09-30    153.002857
# 2022-10-31    145.013333
# 2022-11-30    145.843333
# 2022-12-31    148.060000
# Freq: M, Name: Close, dtype: float64

# %%
df.Close.resample('M').mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.Close.resample('W').mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.Close.resample('Q').mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.Close.resample('M').mean().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.Close.plot()
# Out:
# <AxesSubplot: xlabel='Date'>
