# %%
import pandas as pd

# %%
df = pd.read_csv("LEAVE_CALCULATION.csv")

# %%
df
# Out:
#     Unnamed: 0          Unnamed: 1  \
# 0         CODE               NAME
# 1     JKEPL001     Deepak tripathi
# 2     JKEPL002  Arbind kumar singh
# 3     JKEPL003         Anish Kumar
# 4     JKEPL004       Praduman Giri
# ..         ...                 ...
# 191   JKEPL192  ARUN VISWNATH RAY
# 192   JKEPL193            OM SINGH
# 193   JKEPL194           RAMPUKAR
# 194   JKEPL195         ANUP PANDEY
# 195   JKEPL196         DHARMENDRA
#
#     LEAVE CALCULATION OF EMPLOYEES OF JKEPL (JAN-2021 TO JULY-2021)  \
# 0                                          DESIGNATION
# 1                                          Mech. Engg.
# 2                                             Lab Tech
# 3                                         Store Keeper
# 4                                           Supervisor
# ..                                                 ...
# 191                                     RANTEL TRACTOR
# 192                          RENTAL TRACTOR\nSONALIKA
# 193                               HYVA DRIVER (Rental)
# 194                                     RENTAL TRACTOR
# 195                                         HYDRA OPT.
#
#       Unnamed: 3 Unnamed: 4         Unnamed: 5 Unnamed: 6         Unnamed: 7  \
# 0     PLACE/SITE        JAN  LEAVE CALCULATION        FEB  LEAVE CALCULATION
# 1      Malmaliya         24                  2         28                  3
# 2        Chhapra         30                  3         27                  3
# 3      Malmaliya          0                  0          0                  0
# 4      Malmaliya         31                  3         28                  3
# ..           ...        ...                ...        ...                ...
# 191      DAUDPUR        NaN                NaN        NaN                NaN
# 192   SAHAJITPUR        NaN                NaN        NaN                NaN
# 193    MALMALIYA        NaN                NaN        NaN                NaN
# 194  RACK POINT         NaN                NaN        NaN                NaN
# 195  RACK POINT         NaN                NaN        NaN                NaN
#
#     Unnamed: 8         Unnamed: 9 Unnamed: 10        Unnamed: 11 Unnamed: 12  \
# 0        MARCH  LEAVE CALCULATION       APRIL  LEAVE CALCULATION         MAY
# 1           23                  2          11                  0           0
# 2           25                  3          30                  3          25
# 3            0                  0           0                  0           0
# 4           25                  3          29                  3           0
# ..         ...                ...         ...                ...         ...
# 191        NaN                NaN         NaN                NaN       #REF!
# 192        NaN                NaN         NaN                NaN       #REF!
# 193        NaN                NaN         NaN                NaN       #REF!
# 194        NaN                NaN         NaN                NaN       #REF!
# 195        NaN                NaN         NaN                NaN       #REF!
#
#            Unnamed: 13 Unnamed: 14        Unnamed: 15 Unnamed: 16  \
# 0    LEAVE CALCULATION        JUNE  LEAVE CALCULATION        JULY
# 1                    0           0                  0           0
# 2                    3          28                  3          30
# 3                    0           0                  0           0
# 4                    0          28                  3          31
# ..                 ...         ...                ...         ...
# 191                NaN         NaN                NaN          23
# 192                NaN         NaN                NaN          31
# 193                NaN         NaN                NaN          19
# 194                NaN         NaN                NaN          16
# 195                NaN         NaN                NaN           6
#
#            Unnamed: 17 Unnamed: 18
# 0    LEAVE CALCULATION       TOTAL
# 1                    0           7
# 2                    3          21
# 3                    0           0
# 4                    3          18
# ..                 ...         ...
# 191                  2           2
# 192                  3           3
# 193                  1           1
# 194                  1           1
# 195                  0           0
#
# [196 rows x 19 columns]

# %%
df2 = pd.read_excel("LEAVE CALCULATION OF JKEPL.xlsx")

# %%
df2
# Out:
#     Unnamed: 0          Unnamed: 1  \
# 0         CODE               NAME
# 1     JKEPL001     Deepak tripathi
# 2     JKEPL002  Arbind kumar singh
# 3     JKEPL003         Anish Kumar
# 4     JKEPL004       Praduman Giri
# ..         ...                 ...
# 191   JKEPL192  ARUN VISWNATH RAY
# 192   JKEPL193            OM SINGH
# 193   JKEPL194           RAMPUKAR
# 194   JKEPL195         ANUP PANDEY
# 195   JKEPL196         DHARMENDRA
#
#     LEAVE CALCULATION OF EMPLOYEES OF JKEPL (JAN-2021 TO JULY-2021)  \
# 0                                          DESIGNATION
# 1                                          Mech. Engg.
# 2                                             Lab Tech
# 3                                         Store Keeper
# 4                                           Supervisor
# ..                                                 ...
# 191                                     RANTEL TRACTOR
# 192                          RENTAL TRACTOR\nSONALIKA
# 193                               HYVA DRIVER (Rental)
# 194                                     RENTAL TRACTOR
# 195                                         HYDRA OPT.
#
#       Unnamed: 3 Unnamed: 4         Unnamed: 5 Unnamed: 6         Unnamed: 7  \
# 0     PLACE/SITE        JAN  LEAVE CALCULATION        FEB  LEAVE CALCULATION
# 1      Malmaliya         24                  2         28                  3
# 2        Chhapra         30                  3         27                  3
# 3      Malmaliya          0                  0          0                  0
# 4      Malmaliya         31                  3         28                  3
# ..           ...        ...                ...        ...                ...
# 191      DAUDPUR        NaN                NaN        NaN                NaN
# 192   SAHAJITPUR        NaN                NaN        NaN                NaN
# 193    MALMALIYA        NaN                NaN        NaN                NaN
# 194  RACK POINT         NaN                NaN        NaN                NaN
# 195  RACK POINT         NaN                NaN        NaN                NaN
#
#     Unnamed: 8         Unnamed: 9 Unnamed: 10        Unnamed: 11 Unnamed: 12  \
# 0        MARCH  LEAVE CALCULATION       APRIL  LEAVE CALCULATION         MAY
# 1           23                  2          11                  0           0
# 2           25                  3          30                  3          25
# 3            0                  0           0                  0           0
# 4           25                  3          29                  3           0
# ..         ...                ...         ...                ...         ...
# 191        NaN                NaN         NaN                NaN         NaN
# 192        NaN                NaN         NaN                NaN         NaN
# 193        NaN                NaN         NaN                NaN         NaN
# 194        NaN                NaN         NaN                NaN         NaN
# 195        NaN                NaN         NaN                NaN         NaN
#
#            Unnamed: 13 Unnamed: 14        Unnamed: 15 Unnamed: 16  \
# 0    LEAVE CALCULATION        JUNE  LEAVE CALCULATION        JULY
# 1                    0           0                  0           0
# 2                    3          28                  3          30
# 3                    0           0                  0           0
# 4                    0          28                  3          31
# ..                 ...         ...                ...         ...
# 191                NaN         NaN                NaN          23
# 192                NaN         NaN                NaN          31
# 193                NaN         NaN                NaN          19
# 194                NaN         NaN                NaN          16
# 195                NaN         NaN                NaN           6
#
#            Unnamed: 17 Unnamed: 18
# 0    LEAVE CALCULATION       TOTAL
# 1                    0           7
# 2                    3          21
# 3                    0           0
# 4                    3          18
# ..                 ...         ...
# 191                  2           2
# 192                  3           3
# 193                  1           1
# 194                  1           1
# 195                  0           0
#
# [196 rows x 19 columns]

# %%
weather_data = {
    'day':['1/01/2017','1/02/2017','1/03/2017','1/04/2017','1/05/2017','1/06/2017'],
    'temperatutre':[32,35,28,24,32,32],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']
}

# %%
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#          day  temperatutre  windspeed  event
# 0  1/01/2017            32          6   Rain
# 1  1/02/2017            35          7  Sunny
# 2  1/03/2017            28          2   Snow
# 3  1/04/2017            24          7   Snow
# 4  1/05/2017            32          4   Rain
# 5  1/06/2017            32          2  Sunny

# %%
weather_data = [
   ('1/1/2017',32,6,'Rain'),
   ('1/2/2017',35,7,'Sunny'),
   ('1/3/2017',28,2,'Snow')
    
]

# %%
df = pd.DataFrame(weather_data, columns=["day","temperature","windspeed","event"])

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017','temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017','temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017','temperature': 28, 'windspeed': 2, 'event': 'Snow'},
]

# %%
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
