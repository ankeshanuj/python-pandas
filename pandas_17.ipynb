# %%
import pandas as pd
df = pd.read_csv("appledata_01.csv")
df.head()
# Out:
#       Open    High      Low   Close     Volume
# 0  145.960  148.00  145.650  147.81   65447450
# 1  148.210  149.13  146.610  148.31   71250420
# 2  141.395  148.72  140.550  148.03  111380900
# 3  144.290  144.81  140.355  141.17   83763800
# 4  145.140  146.64  143.380  144.22   69346520

# %%
rng = pd.date_range(start="12/03/2021",end="12/01/2022", freq='B')
rng
# Out:
# DatetimeIndex(['2021-12-03', '2021-12-06', '2021-12-07', '2021-12-08',
#                '2021-12-09', '2021-12-10', '2021-12-13', '2021-12-14',
#                '2021-12-15', '2021-12-16',
#                ...
#                '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23',
#                '2022-11-24', '2022-11-25', '2022-11-28', '2022-11-29',
#                '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', length=260, freq='B')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#                Open      High       Low   Close     Volume
# 2021-12-03  145.960  148.0000  145.6500  147.81   65447450
# 2021-12-06  148.210  149.1300  146.6100  148.31   71250420
# 2021-12-07  141.395  148.7200  140.5500  148.03  111380900
# 2021-12-08  144.290  144.8100  140.3550  141.17   83763800
# 2021-12-09  145.140  146.6400  143.3800  144.22   69346520
# ...             ...       ...       ...     ...        ...
# 2022-11-25  172.700  175.3000  171.6400  172.00   96903960
# 2022-11-28  179.610  180.1700  174.6400  174.92   94537600
# 2022-11-29  172.860  173.9458  170.9500  171.66   77251200
# 2022-11-30  171.680  174.1000  170.6800  172.39   82465400
# 2022-12-01  152.215  153.5900  148.5613  150.04   89868330
#
# [260 rows x 5 columns]

# %%
 # %matplotlib inline
df.Close.plot()
# Out:
# <AxesSubplot: >

# %%
df["2021-12-03":"2021-12-09"]
# Out:
#                Open    High      Low   Close     Volume
# 2021-12-03  145.960  148.00  145.650  147.81   65447450
# 2021-12-06  148.210  149.13  146.610  148.31   71250420
# 2021-12-07  141.395  148.72  140.550  148.03  111380900
# 2021-12-08  144.290  144.81  140.355  141.17   83763800
# 2021-12-09  145.140  146.64  143.380  144.22   69346520

# %%
df["2021-12-03":"2021-12-09"].Close.mean()
# Out:
# 145.908

# %%
df.asfreq('D',method='pad')
# Out:
#                Open      High       Low   Close     Volume
# 2021-12-03  145.960  148.0000  145.6500  147.81   65447450
# 2021-12-04  145.960  148.0000  145.6500  147.81   65447450
# 2021-12-05  145.960  148.0000  145.6500  147.81   65447450
# 2021-12-06  148.210  149.1300  146.6100  148.31   71250420
# 2021-12-07  141.395  148.7200  140.5500  148.03  111380900
# ...             ...       ...       ...     ...        ...
# 2022-11-27  172.700  175.3000  171.6400  172.00   96903960
# 2022-11-28  179.610  180.1700  174.6400  174.92   94537600
# 2022-11-29  172.860  173.9458  170.9500  171.66   77251200
# 2022-11-30  171.680  174.1000  170.6800  172.39   82465400
# 2022-12-01  152.215  153.5900  148.5613  150.04   89868330
#
# [364 rows x 5 columns]

# %%
df.asfreq('W',method='pad')
# Out:
#                Open      High       Low   Close     Volume
# 2021-12-05  145.960  148.0000  145.6500  147.81   65447450
# 2021-12-12  148.305  148.8800  147.1200  148.11   35195860
# 2021-12-19  146.430  151.4800  146.1500  150.72   80389400
# 2021-12-26  141.240  146.8700  139.5000  146.87  118854000
# 2022-01-02  142.060  142.8000  138.7500  138.88   97918520
# 2022-01-09  148.070  149.0460  144.1300  144.80  109180200
# 2022-01-16  143.020  145.8900  142.6500  143.39   64521990
# 2022-01-23  134.990  143.5900  134.3700  142.99  113224000
# 2022-01-30  145.810  147.5400  145.2200  145.43   68402170
# 2022-02-06  146.100  146.7200  140.6800  142.48  128138200
# 2022-02-13  152.380  154.4700  150.9100  152.74   86652540
# 2022-02-20  154.650  155.2400  151.3800  152.37   90481110
# 2022-02-27  154.640  156.3600  152.6800  154.46   84923850
# 2022-03-06  160.305  160.5800  157.1400  157.22   87991090
# 2022-03-13  167.320  168.1100  166.2450  167.53   53841520
# ...

# %%
df.asfreq('H',method='pad')
# Out:
#                         Open    High       Low   Close    Volume
# 2021-12-03 00:00:00  145.960  148.00  145.6500  147.81  65447450
# 2021-12-03 01:00:00  145.960  148.00  145.6500  147.81  65447450
# 2021-12-03 02:00:00  145.960  148.00  145.6500  147.81  65447450
# 2021-12-03 03:00:00  145.960  148.00  145.6500  147.81  65447450
# 2021-12-03 04:00:00  145.960  148.00  145.6500  147.81  65447450
# ...                      ...     ...       ...     ...       ...
# 2022-11-30 20:00:00  171.680  174.10  170.6800  172.39  82465400
# 2022-11-30 21:00:00  171.680  174.10  170.6800  172.39  82465400
# 2022-11-30 22:00:00  171.680  174.10  170.6800  172.39  82465400
# 2022-11-30 23:00:00  171.680  174.10  170.6800  172.39  82465400
# 2022-12-01 00:00:00  152.215  153.59  148.5613  150.04  89868330
#
# [8713 rows x 5 columns]

# %%
rng = pd.date_range(start="01/01/2017",periods=72,freq='B')
rng
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11',
#                '2017-01-12', '2017-01-13', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02',
#                '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08',
#                '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14',
#                '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-20',
#                '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24',
#                '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10', '2017-03-13', '2017-03-14',
# ...

# %%
rng = pd.date_range(start="01/01/2017",periods=72,freq='H')
rng
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                '2017-01-01 10:00:00', '2017-01-01 11:00:00',
#                '2017-01-01 12:00:00', '2017-01-01 13:00:00',
#                '2017-01-01 14:00:00', '2017-01-01 15:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 17:00:00',
#                '2017-01-01 18:00:00', '2017-01-01 19:00:00',
#                '2017-01-01 20:00:00', '2017-01-01 21:00:00',
#                '2017-01-01 22:00:00', '2017-01-01 23:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 01:00:00',
#                '2017-01-02 02:00:00', '2017-01-02 03:00:00',
#                '2017-01-02 04:00:00', '2017-01-02 05:00:00',
# ...

# %%
import numpy as np
np.random.randint(1,10,len(rng))
# Out:
# array([9, 7, 3, 8, 7, 1, 7, 1, 2, 8, 7, 7, 4, 4, 1, 5, 8, 4, 1, 3, 4, 5,
#        3, 3, 3, 9, 6, 4, 9, 9, 5, 4, 2, 5, 3, 4, 9, 3, 6, 7, 7, 7, 6, 3,
#        3, 3, 5, 5, 5, 8, 6, 9, 3, 6, 1, 6, 7, 3, 2, 4, 1, 5, 4, 2, 1, 1,
#        4, 5, 4, 5, 2, 8])

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(rng)), index=rng)
ts.head(10)
# Out:
# 2017-01-01 00:00:00    4
# 2017-01-01 01:00:00    6
# 2017-01-01 02:00:00    3
# 2017-01-01 03:00:00    2
# 2017-01-01 04:00:00    3
# 2017-01-01 05:00:00    4
# 2017-01-01 06:00:00    7
# 2017-01-01 07:00:00    5
# 2017-01-01 08:00:00    1
# 2017-01-01 09:00:00    7
# Freq: H, dtype: int32
